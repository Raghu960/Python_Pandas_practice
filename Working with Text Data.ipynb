# %%
import pandas as pd

# %%
cg=pd.read_csv(r"F:\4-1 Files\Udemy - Data Analysis with Pandas and Python\1. Installation and Setup\1.1 pandas.zip\chicago.csv").dropna(how="all")
cg["Department"]=cg["Department"].astype("category")
cg.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
cg.head()
cg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
cg["Department"].nunique()
# Out:
# 35

# %%
cg["Position Title"].str.title()
# Out:
# 0                                     Water Rate Taker
# 1                                       Police Officer
# 2                                       Police Officer
# 3                             Chief Contract Expediter
# 4                                    Civil Engineer Iv
# 5                                 Asst To The Alderman
# 6                                General Laborer - Dss
# 7                          Traffic Control Aide-Hourly
# 8                           Staff Asst To The Alderman
# 9                                  Electrical Mechanic
# 10                                   Fire Engineer-Emt
# 11                                      Police Officer
# 12                                  Foster Grandparent
# 13                                           Clerk Iii
# 14                              Investigator - Ipra Ii
# 15                                      Police Officer
# 16                                      Police Officer
# ...

# %%
cg["Department"].str.len()
# Out:
# 0        11.0
# 1         6.0
# 2         6.0
# 3        16.0
# 4        11.0
# 5        12.0
# 6        13.0
# 7         4.0
# 8        12.0
# 9         8.0
# 10        4.0
# 11        6.0
# 12       16.0
# 13        6.0
# 14        4.0
# 15        6.0
# 16        6.0
# 17        4.0
# 18        6.0
# 19        4.0
# 20       11.0
# 21        4.0
# 22        4.0
# 23        4.0
# 24       16.0
# 25       11.0
# 26       13.0
# 27       16.0
# 28        6.0
# 29        4.0
#          ...
# 32033     6.0
# 32034     6.0
# 32035     6.0
# 32036    13.0
# 32037     4.0
# 32038    11.0
# 32039     4.0
# 32040     6.0
# 32041     4.0
# 32042    16.0
# 32043    13.0
# 32044     6.0
# 32045     4.0
# 32046     7.0
# 32047     6.0
# 32048     3.0
# 32049     4.0
# 32050    11.0
# 32051     8.0
# 32052     6.0
# 32053     4.0
# 32054     6.0
# 32055     6.0
# 32056    16.0
# 32057    16.0
# 32058     6.0
# 32059     6.0
# 32060     6.0
# 32061     4.0
# 32062     NaN
# ...

# %%
cg["Department"]=cg["Department"].str.replace("MGMNT","MANAGEMENT")

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
"Hello World".replace("Hello","Hi")
# Out:
# 'Hi World'

# %%
cg["Employee Annual Salary"]=cg["Employee Annual Salary"].str.replace("$","").astype("float")

# %%
cg["Employee Annual Salary"].nlargest()
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# Name: Employee Annual Salary, dtype: float64

# %%
cg.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MANAGEMENT
# 1  AARON,  JEFFERY M    POLICE OFFICER            POLICE
# 2     AARON,  KARINA    POLICE OFFICER            POLICE
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0

# %%
mask=cg["Position Title"].str.lower().str.contains("water")
cg[mask]
# Out:
#                           Name                                 Position Title  \
# 0              AARON,  ELVIA J                               WATER RATE TAKER
# 554         ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671            ANDER,  PERRY A                               WATER CHEMIST II
# 685        ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702          ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# 1054          ASHLEY,  KARMA T                               WATER CHEMIST II
# 1079         ATKINS,  JOANNA M                               WATER CHEMIST II
# 1181        AZEEM,  MOHAMMED A                               WATER CHEMIST II
# 1285            BAJIC,  JOHN A                          WATER METER MACHINIST
# 2400          BOLTON,  BRIAN E                               WATER RATE TAKER
# 2586           BOYCE,  ADNER L                               WATER CHEMIST II
# ...

# %%
cg["Position Title"].str.lower().str.startswith('water')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 32032    False
# 32033    False
# 32034    False
# 32035    False
# 32036    False
# 32037    False
# 32038    False
# 32039    False
# 32040    False
# 32041    False
# 32042    False
# 32043    False
# 32044    False
# 32045    False
# 32046    False
# 32047    False
# 32048    False
# 32049    False
# 32050    False
# 32051    False
# 32052    False
# 32053    False
# 32054    False
# 32055    False
# 32056    False
# 32057    False
# 32058    False
# ...

# %%
"  Hello World ".lstrip()
# Out:
# 'Hello World '

# %%
" Hello World ".strip()
# Out:
# 'Hello World'

# %%
cg["Name"].str.strip()
# Out:
# 0                 AARON,  ELVIA J
# 1               AARON,  JEFFERY M
# 2                  AARON,  KARINA
# 3             AARON,  KIMBERLEI R
# 4             ABAD JR,  VICENTE M
# 5                 ABARCA,  ANABEL
# 6               ABARCA,  EMMANUEL
# 7               ABASCAL,  REECE E
# 8            ABBASI,  CHRISTOPHER
# 9           ABBATACOLA,  ROBERT J
# 10          ABBATEMARCO,  JAMES J
# 11               ABBATE,  TERRY M
# 12               ABBOTT,  BETTY L
# 13              ABBOTT,  LYNISE M
# 14         ABBRUZZESE,  WILLIAM J
# 15                ABDALLAH,  ZAID
# 16          ABDELHADI,  ABDALMAHD
# 17            ABDELLATIF,  AREF R
# 18             ABDELMAJEID,  AZIZ
# 19            ABDOLLAHZADEH,  ALI
# 20       ABDUL-KARIM,  MUHAMMAD A
# 21            ABDULLAH,  DANIEL N
# 22               ABDULLAH,  KEVIN
# 23           ABDULLAH,  LAKENYA N
# 24            ABDULLAH,  RASHAD J
# 25           ABDULSATTAR,  MUDHAR
# 26           ABDUL-SHAKUR,  TAHIR
# ...

# %%
cg["Position Title"].str.strip()
# Out:
# 0                                     WATER RATE TAKER
# 1                                       POLICE OFFICER
# 2                                       POLICE OFFICER
# 3                             CHIEF CONTRACT EXPEDITER
# 4                                    CIVIL ENGINEER IV
# 5                                 ASST TO THE ALDERMAN
# 6                                GENERAL LABORER - DSS
# 7                          TRAFFIC CONTROL AIDE-HOURLY
# 8                           STAFF ASST TO THE ALDERMAN
# 9                                  ELECTRICAL MECHANIC
# 10                                   FIRE ENGINEER-EMT
# 11                                      POLICE OFFICER
# 12                                  FOSTER GRANDPARENT
# 13                                           CLERK III
# 14                              INVESTIGATOR - IPRA II
# 15                                      POLICE OFFICER
# 16                                      POLICE OFFICER
# ...

# %%
cg.index=cg.index.str.strip().str.title()

# %%
cg.columns=cg.columns.str.upper()

# %%
cg.tail()
# Out:
#       First Name    Last Name                 Name  \
# 32057    Zygadlo    Michael J  ZYGADLO,  MICHAEL J
# 32058   Zygowicz      Peter J   ZYGOWICZ,  PETER J
# 32059   Zymantas       Mark E    ZYMANTAS,  MARK E
# 32060  Zyrkowski      Carlo E  ZYRKOWSKI,  CARLO E
# 32061  Zyskowski      Dariusz  ZYSKOWSKI,  DARIUSZ
#
#                        Position Title        Department Employee Annual Salary
# 32057  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES              $99528.00
# 32058                  POLICE OFFICER            POLICE              $87384.00
# 32059                  POLICE OFFICER            POLICE              $84450.00
# 32060                  POLICE OFFICER            POLICE              $87384.00
# 32061         CHIEF DATA BASE ANALYST              DoIT             $113664.00

# %%
"Hello|W|orld".split('|')
# Out:
# ['Hello', 'W', 'orld']

# %%
fname=cg["Name"].str.split(",").str.get(0).str.title()

# %%
cg.insert(0,"First Name",fname)

# %%
cg.drop(axis=1,columns="Name")
# Out:
#            First Name      Last Name  \
# 0               Aaron        Elvia J
# 1               Aaron      Jeffery M
# 2               Aaron         Karina
# 3               Aaron    Kimberlei R
# 4             Abad Jr      Vicente M
# 5              Abarca         Anabel
# 6              Abarca       Emmanuel
# 7             Abascal        Reece E
# 8              Abbasi    Christopher
# 9          Abbatacola       Robert J
# 10        Abbatemarco        James J
# 11             Abbate        Terry M
# 12             Abbott        Betty L
# 13             Abbott       Lynise M
# 14         Abbruzzese      William J
# 15           Abdallah           Zaid
# 16          Abdelhadi      Abdalmahd
# 17         Abdellatif         Aref R
# 18        Abdelmajeid           Aziz
# 19      Abdollahzadeh            Ali
# 20        Abdul-Karim     Muhammad A
# 21           Abdullah       Daniel N
# 22           Abdullah          Kevin
# 23           Abdullah      Lakenya N
# ...

# %%
lname=cg["Name"].str.split(",").str.get(1).str.title()

# %%
cg.insert(1,"Last Name",lname)

# %%
cg["Last Name"].apply(lambda x:len(x))
# Out:
# 0         9
# 1        11
# 2         8
# 3        13
# 4        11
# 5         8
# 6        10
# 7         9
# 8        13
# 9        10
# 10        9
# 11        9
# 12        9
# 13       10
# 14       11
# 15        6
# 16       11
# 17        8
# 18        6
# 19        5
# 20       12
# 21       10
# 22        7
# 23       11
# 24       10
# 25        8
# 26        7
# 27       11
# 28        9
# 29        8
#          ..
# 32032     7
# 32033     8
# 32034     7
# 32035     8
# 32036     8
# 32037     9
# 32038     6
# 32039     8
# 32040     7
# 32041     9
# 32042     9
# 32043     7
# 32044     8
# 32045     9
# 32046     8
# 32047     8
# 32048     8
# 32049     9
# 32050    10
# 32051     9
# 32052    11
# 32053    11
# 32054     9
# 32055     7
# 32056     8
# 32057    11
# 32058     9
# 32059     8
# 32060     9
# 32061     9
# Name: Last Name, Length: 32062, dtype: int64

# %%
cg["Name"].str.split(",").str.strip()
# Out:
# 0                 [AARON,   ELVIA J]
# 1               [AARON,   JEFFERY M]
# 2                  [AARON,   KARINA]
# 3             [AARON,   KIMBERLEI R]
# 4             [ABAD JR,   VICENTE M]
# 5                 [ABARCA,   ANABEL]
# 6               [ABARCA,   EMMANUEL]
# 7               [ABASCAL,   REECE E]
# 8            [ABBASI,   CHRISTOPHER]
# 9           [ABBATACOLA,   ROBERT J]
# 10          [ABBATEMARCO,   JAMES J]
# 11               [ABBATE,   TERRY M]
# 12               [ABBOTT,   BETTY L]
# 13              [ABBOTT,   LYNISE M]
# 14         [ABBRUZZESE,   WILLIAM J]
# 15                [ABDALLAH,   ZAID]
# 16          [ABDELHADI,   ABDALMAHD]
# 17            [ABDELLATIF,   AREF R]
# 18             [ABDELMAJEID,   AZIZ]
# 19            [ABDOLLAHZADEH,   ALI]
# 20       [ABDUL-KARIM,   MUHAMMAD A]
# 21            [ABDULLAH,   DANIEL N]
# 22               [ABDULLAH,   KEVIN]
# 23           [ABDULLAH,   LAKENYA N]
# 24            [ABDULLAH,   RASHAD J]
# ...

# %%
cg["Last Name"].str.strip().str.split(" ").str.get(0).value_counts().head()
# Out:
# Michael    1153
# John        899
# James       676
# Robert      622
# Joseph      537
# Name: Last Name, dtype: int64

# %%
cg[["fTitle","Rwords"]]=cg["Position Title"].str.split(" ",expand=True,n=1)

# %%
cg.tail(3)
# Out:
#       First Name  Last Name                 Name           Position Title  \
# 32059   Zymantas     Mark E    ZYMANTAS,  MARK E           POLICE OFFICER
# 32060  Zyrkowski    Carlo E  ZYRKOWSKI,  CARLO E           POLICE OFFICER
# 32061  Zyskowski    Dariusz  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST
#
#       Department Employee Annual Salary  fTitle             Rwords
# 32059     POLICE              $84450.00  POLICE            OFFICER
# 32060     POLICE              $87384.00  POLICE            OFFICER
# 32061       DoIT             $113664.00   CHIEF  DATA BASE ANALYST
