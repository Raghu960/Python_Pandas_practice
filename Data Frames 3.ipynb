# %%
import pandas as pd

# %%
jb=pd.read_csv(r"F:\4-1 Files\Udemy - Data Analysis with Pandas and Python\1. Installation and Setup\1.1 pandas.zip\jamesbond.csv")

# %%
jb.head(5)
# Out:
#                                Film  Year       Director  Box Office  Budget  \
# Actor
# Sean Connery                 Dr. No  1962  Terence Young       448.8     7.0
# Sean Connery  From Russia with Love  1963  Terence Young       543.8    12.6
# Sean Connery             Goldfinger  1964   Guy Hamilton       820.4    18.6
# Sean Connery            Thunderball  1965  Terence Young       848.1    41.9
# David Niven           Casino Royale  1967     Ken Hughes       315.0    85.0
#
#               Bond Actor Salary
# Actor
# Sean Connery                0.6
# Sean Connery                1.6
# Sean Connery                3.2
# Sean Connery                4.7
# David Niven                 NaN

# %%
jb.set_index("Actor",inplace=True)

# %%
jb.reset_index(drop = False,inplace=True)

# %%
jb.set_index("Year")
# Out:
#                                  Film            Director  Box Office  Budget  \
# Year
# 1962                           Dr. No       Terence Young       448.8     7.0
# 1963            From Russia with Love       Terence Young       543.8    12.6
# 1964                       Goldfinger        Guy Hamilton       820.4    18.6
# 1965                      Thunderball       Terence Young       848.1    41.9
# 1967                    Casino Royale          Ken Hughes       315.0    85.0
# 1967              You Only Live Twice       Lewis Gilbert       514.2    59.9
# 1969  On Her Majesty's Secret Service       Peter R. Hunt       291.5    37.3
# 1971             Diamonds Are Forever        Guy Hamilton       442.5    34.7
# 1973                 Live and Let Die        Guy Hamilton       460.3    30.8
# 1974      The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# 1977             The Spy Who Loved Me       Lewis Gilbert       533.0    45.1
# ...

# %%
jb.head()
jb.sort_index()
# Out:
#                                            Film  Year            Director  \
# Actor
# Daniel Craig                            Spectre  2015          Sam Mendes
# Daniel Craig                  Quantum of Solace  2008        Marc Forster
# Daniel Craig                      Casino Royale  2006     Martin Campbell
# Daniel Craig                            Skyfall  2012          Sam Mendes
# David Niven                       Casino Royale  1967          Ken Hughes
# George Lazenby  On Her Majesty's Secret Service  1969       Peter R. Hunt
# Pierce Brosnan                  Die Another Day  2002        Lee Tamahori
# Pierce Brosnan          The World Is Not Enough  1999       Michael Apted
# Pierce Brosnan              Tomorrow Never Dies  1997  Roger Spottiswoode
# Pierce Brosnan                        GoldenEye  1995     Martin Campbell
# Roger Moore                    A View to a Kill  1985           John Glen
# Roger Moore                           Octopussy  1983           John Glen
# ...

# %%
st={4,1,2,3,4,1,1,}
st
# Out:
# {1, 2, 3, 4}

# %%
type(st)
# Out:
# set

# %%
jb.loc[["David Niven","Timothy Dalton","raghu"]]
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                                 Film    Year    Director  Box Office  Budget  \
# Actor
# David Niven            Casino Royale  1967.0  Ken Hughes       315.0    85.0
# Timothy Dalton  The Living Daylights  1987.0   John Glen       313.5    68.8
# Timothy Dalton       Licence to Kill  1989.0   John Glen       250.9    56.7
# raghu                            NaN     NaN         NaN         NaN     NaN
#
#                 Bond Actor Salary
# Actor
# David Niven                   NaN
# Timothy Dalton                5.2
# Timothy Dalton                7.9
# raghu                         NaN

# %%
jb.reset_index(inplace=True)

# %%
jb.set_index("Film",inplace=True)

# %%
jb.sort_index(inplace=True)

# %%
jb.head()
# Out:
#                                Actor  Year         Director  Box Office  \
# Film
# A View to a Kill         Roger Moore  1985        John Glen       275.2
# Casino Royale           Daniel Craig  2006  Martin Campbell       581.5
# Casino Royale            David Niven  1967       Ken Hughes       315.0
# Diamonds Are Forever    Sean Connery  1971     Guy Hamilton       442.5
# Die Another Day       Pierce Brosnan  2002     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
jb.iloc[:5]
# Out:
#                                Actor  Year         Director  Box Office  \
# Film
# A View to a Kill         Roger Moore  1985        John Glen       275.2
# Casino Royale           Daniel Craig  2006  Martin Campbell       581.5
# Casino Royale            David Niven  1967       Ken Hughes       315.0
# Diamonds Are Forever    Sean Connery  1971     Guy Hamilton       442.5
# Die Another Day       Pierce Brosnan  2002     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
jb.ix[["GoldenEye","bond"]]
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                     Actor    Year         Director  Box Office  Budget  \
# Film
# GoldenEye  Pierce Brosnan  1995.0  Martin Campbell       518.5    76.9
# bond                  NaN     NaN              NaN         NaN     NaN
#
# ...

# %%
jb.ix[25:]
jb.ix[[16,11,1]]
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                           Actor  Year         Director  Box Office  Budget  \
# Film
# Quantum of Solace  Daniel Craig  2008     Marc Forster       514.2   181.4
# Live and Let Die    Roger Moore  1973     Guy Hamilton       460.3    30.8
# Casino Royale      Daniel Craig  2006  Martin Campbell       581.5   145.3
#
# ...

# %%
jb.iloc[1,[2,5]]
# Out:
# Director             Martin Campbell
# Bond Actor Salary                3.3
# Name: Casino Royale, dtype: object

# %%
jb.loc[:,"Actor":"Budget"]
# Out:
#                                           Actor  Year            Director  \
# Film
# A View to a Kill                    Roger Moore  1985           John Glen
# Casino Royale                      Daniel Craig  2006     Martin Campbell
# Casino Royale                       David Niven  1967          Ken Hughes
# Diamonds Are Forever               Sean Connery  1971        Guy Hamilton
# Die Another Day                  Pierce Brosnan  2002        Lee Tamahori
# Dr. No                             Sean Connery  1962       Terence Young
# For Your Eyes Only                  Roger Moore  1981           John Glen
# From Russia with Love              Sean Connery  1963       Terence Young
# GoldenEye                        Pierce Brosnan  1995     Martin Campbell
# Goldfinger                         Sean Connery  1964        Guy Hamilton
# Licence to Kill                  Timothy Dalton  1989           John Glen
# Live and Let Die                    Roger Moore  1973        Guy Hamilton
# ...

# %%
jb.ix[25,["Actor","Budegt"]]
jb.ix[5,0]
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 'Sean Connery'

# %%
jb.ix[2,5]=''
jb.ix[2,5]
jb.head(3)
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                          Actor  Year         Director  Box Office  Budget  \
# Film
# A View to a Kill   Roger Moore  1985        John Glen       275.2    54.5
# Casino Royale     Daniel Craig  2006  Martin Campbell       581.5   145.3
# Casino Royale      David Niven  1967       Ken Hughes       315.0    85.0
#
# ...

# %%
mask=jb["Actor"]=='Sean Connery'

# %%
jb[mask]
# Out:
#                                   Actor  Year        Director  Box Office  \
# Film
# Diamonds Are Forever   Sir Sean COnnery  1971    Guy Hamilton       442.5
# Dr. No                 Sir Sean COnnery  1962   Terence Young       448.8
# From Russia with Love  Sir Sean COnnery  1963   Terence Young       543.8
# Goldfinger             Sir Sean COnnery  1964    Guy Hamilton       820.4
# Never Say Never Again  Sir Sean COnnery  1983  Irvin Kershner       380.0
# Thunderball            Sir Sean COnnery  1965   Terence Young       848.1
# You Only Live Twice    Sir Sean COnnery  1967   Lewis Gilbert       514.2
#
#                        Budget Bond Actor Salary
# Film
# Diamonds Are Forever     34.7               5.8
# Dr. No                    7.0               0.6
# From Russia with Love    12.6               1.6
# Goldfinger               18.6               3.2
# Never Say Never Again    86.0               NaN
# Thunderball              41.9               4.7
# ...

# %%
rd["Actor"]='Sir Sean Connery'
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
jb[mask]["Actor"]=rd["Actor"]
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
jb.ix[mask,"Actor"]='Sir Sean COnnery'
# Out:
# G:\Program_Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
jb.head(10)
# Out:
#                                   Actor  Year         Director  Box Office  \
# Film
# A View to a Kill            Roger Moore  1985        John Glen       275.2
# Casino Royale              Daniel Craig  2006  Martin Campbell       581.5
# Casino Royale               David Niven  1967       Ken Hughes       315.0
# Diamonds Are Forever   Sir Sean COnnery  1971     Guy Hamilton       442.5
# Die Another Day          Pierce Brosnan  2002     Lee Tamahori       465.4
# Dr. No                 Sir Sean COnnery  1962    Terence Young       448.8
# For Your Eyes Only          Roger Moore  1981        John Glen       449.4
# From Russia with Love  Sir Sean COnnery  1963    Terence Young       543.8
# GoldenEye                Pierce Brosnan  1995  Martin Campbell       518.5
# Goldfinger             Sir Sean COnnery  1964     Guy Hamilton       820.4
#
#                        Budget Bond Actor Salary
# Film
# A View to a Kill         54.5               9.1
# ...

# %%
jb.rename(index={"A View to a Kill":"AVK"},columns={"Year":"Release Year"})
# Out:
#                                             Actor  Release Year  \
# Film
# AVK                                   Roger Moore          1985
# Casino Royale                        Daniel Craig          2006
# Casino Royale                         David Niven          1967
# Diamonds Are Forever             Sir Sean COnnery          1971
# Die Another Day                    Pierce Brosnan          2002
# Dr. No                           Sir Sean COnnery          1962
# For Your Eyes Only                    Roger Moore          1981
# From Russia with Love            Sir Sean COnnery          1963
# GoldenEye                          Pierce Brosnan          1995
# Goldfinger                       Sir Sean COnnery          1964
# Licence to Kill                    Timothy Dalton          1989
# Live and Let Die                      Roger Moore          1973
# Moonraker                             Roger Moore          1979
# Never Say Never Again            Sir Sean COnnery          1983
# ...

# %%
jb.drop("Spectre")
jb.drop(["Actor","Budget"],axis=1)
# Out:
#                                  Year            Director  Box Office  \
# Film
# A View to a Kill                 1985           John Glen       275.2
# Casino Royale                    2006     Martin Campbell       581.5
# Casino Royale                    1967          Ken Hughes       315.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5
# Die Another Day                  2002        Lee Tamahori       465.4
# Dr. No                           1962       Terence Young       448.8
# For Your Eyes Only               1981           John Glen       449.4
# From Russia with Love            1963       Terence Young       543.8
# GoldenEye                        1995     Martin Campbell       518.5
# Goldfinger                       1964        Guy Hamilton       820.4
# Licence to Kill                  1989           John Glen       250.9
# Live and Let Die                 1973        Guy Hamilton       460.3
# ...

# %%
Revenue=jb.pop("Budget")

# %%
jb["Revenue"]=Revenue

# %%
jb.head(9)
# Out:
#                                   Actor  Year         Director  Budget  \
# Film
# A View to a Kill            Roger Moore  1985        John Glen    54.5
# Casino Royale              Daniel Craig  2006  Martin Campbell   145.3
# Casino Royale               David Niven  1967       Ken Hughes    85.0
# Diamonds Are Forever   Sir Sean COnnery  1971     Guy Hamilton    34.7
# Die Another Day          Pierce Brosnan  2002     Lee Tamahori   154.2
# Dr. No                 Sir Sean COnnery  1962    Terence Young     7.0
# For Your Eyes Only          Roger Moore  1981        John Glen    60.2
# From Russia with Love  Sir Sean COnnery  1963    Terence Young    12.6
# GoldenEye                Pierce Brosnan  1995  Martin Campbell    76.9
#
#                        Box Office Bond Actor Salary
# Film
# A View to a Kill            275.2               9.1
# Casino Royale               581.5               3.3
# Casino Royale               315.0
# ...

# %%
jb.insert(3,"Budget",Revenue)

# %%
jb.drop("Revenue",axis=1,inplace=True)

# %%
jb.sample(1,axis=1)
# Out:
#                                            Director
# Film
# A View to a Kill                          John Glen
# Casino Royale                       Martin Campbell
# Casino Royale                            Ken Hughes
# Diamonds Are Forever                   Guy Hamilton
# Die Another Day                        Lee Tamahori
# Dr. No                                Terence Young
# For Your Eyes Only                        John Glen
# From Russia with Love                 Terence Young
# GoldenEye                           Martin Campbell
# Goldfinger                             Guy Hamilton
# Licence to Kill                           John Glen
# Live and Let Die                       Guy Hamilton
# Moonraker                             Lewis Gilbert
# Never Say Never Again                Irvin Kershner
# Octopussy                                 John Glen
# On Her Majesty's Secret Service       Peter R. Hunt
# Quantum of Solace                      Marc Forster
# ...

# %%
jb.nlargest(3,"Box Office")
jb.nsmallest(3,"Box Office")
# Out:
#                                           Actor  Year       Director  Budget  \
# Film
# Licence to Kill                  Timothy Dalton  1989      John Glen    56.7
# A View to a Kill                    Roger Moore  1985      John Glen    54.5
# On Her Majesty's Secret Service  George Lazenby  1969  Peter R. Hunt    37.3
#
#                                  Box Office Bond Actor Salary
# Film
# Licence to Kill                       250.9               7.9
# A View to a Kill                      275.2               9.1
# On Her Majesty's Secret Service       291.5               0.6

# %%
jb.where(mask)
# Out:
#                                           Actor    Year   Director  Budget  \
# Film
# A View to a Kill                            NaN     NaN        NaN     NaN
# Casino Royale                               NaN     NaN        NaN     NaN
# Casino Royale                               NaN     NaN        NaN     NaN
# Diamonds Are Forever                        NaN     NaN        NaN     NaN
# Die Another Day                             NaN     NaN        NaN     NaN
# Dr. No                                      NaN     NaN        NaN     NaN
# For Your Eyes Only                          NaN     NaN        NaN     NaN
# From Russia with Love                       NaN     NaN        NaN     NaN
# GoldenEye                                   NaN     NaN        NaN     NaN
# Goldfinger                                  NaN     NaN        NaN     NaN
# Licence to Kill                  Timothy Dalton  1989.0  John Glen    56.7
# ...

# %%
mask=jb["Year"]==1989

# %%
jb.query('Year>1950')
# Out:
#                                             Actor  Year            Director  \
# Film
# A View to a Kill                      Roger Moore  1985           John Glen
# Casino Royale                        Daniel Craig  2006     Martin Campbell
# Casino Royale                         David Niven  1967          Ken Hughes
# Diamonds Are Forever             Sir Sean COnnery  1971        Guy Hamilton
# Die Another Day                    Pierce Brosnan  2002        Lee Tamahori
# Dr. No                           Sir Sean COnnery  1962       Terence Young
# For Your Eyes Only                    Roger Moore  1981           John Glen
# From Russia with Love            Sir Sean COnnery  1963       Terence Young
# GoldenEye                          Pierce Brosnan  1995     Martin Campbell
# Goldfinger                       Sir Sean COnnery  1964        Guy Hamilton
# Licence to Kill                    Timothy Dalton  1989           John Glen
# ...

# %%
def convert_to_string(number):
    return str(number) + 'millions'

jb["Budget"]=jb["Budget"].apply(convert_to_string)

# %%
jb.head(3)
# Out:
#                          Actor  Year         Director         Budget  \
# Film
# A View to a Kill   Roger Moore  1985        John Glen   54.5millions
# Casino Royale     Daniel Craig  2006  Martin Campbell  145.3millions
# Casino Royale      David Niven  1967       Ken Hughes   85.0millions
#
#                   Box Office Bond Actor Salary
# Film
# A View to a Kill       275.2               9.1
# Casino Royale          581.5               3.3
# Casino Royale          315.0

# %%
columns=["Box Office", "Bond Actor Salary"]

for i in columns:
    jb[i]=jb[i].apply(convert_to_string)

# %%
jb.head(3)
# Out:
#                          Actor  Year         Director         Budget  \
# Film
# A View to a Kill   Roger Moore  1985        John Glen   54.5millions
# Casino Royale     Daniel Craig  2006  Martin Campbell  145.3millions
# Casino Royale      David Niven  1967       Ken Hughes   85.0millions
#
#                      Box Office Bond Actor Salary
# Film
# A View to a Kill  275.2millions       9.1millions
# Casino Royale     581.5millions       3.3millions
# Casino Royale     315.0millions          millions

# %%
release_date=jb["Year"].copy()

# %%
release_date.head(3)
# Out:
# Film
# A View to a Kill    1986
# Casino Royale       2006
# Casino Royale       1967
# Name: Year, dtype: int64

# %%
release_date["A View to a Kill"]=1986
