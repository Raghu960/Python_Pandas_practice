# %%
import pandas as pd

# %%
df=pd.read_csv("../Downloads/Datasets/1000 Records.csv",parse_dates=['Date of Birth','Time of Birth','Date of Joining'])

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
# Emp ID             1000 non-null int64
# Name Prefix        1000 non-null category
# First Name         1000 non-null object
# Gender             1000 non-null category
# E Mail             1000 non-null object
# Date of Birth      1000 non-null datetime64[ns]
# Time of Birth      1000 non-null datetime64[ns]
# Age in Yrs.        1000 non-null float64
# Weight in Kgs.     1000 non-null int64
# Date of Joining    1000 non-null datetime64[ns]
# Salary             1000 non-null int64
# County             1000 non-null object
# City               1000 non-null object
# State              1000 non-null object
# dtypes: category(2), datetime64[ns](3), float64(1), int64(3), object(5)
# memory usage: 96.2+ KB

# %%
df.drop(axis=1,columns=df.loc[:,"Zip":"Password"],inplace=True)

# %%
df['Name Prefix']=df['Name Prefix'].astype("category")

# %%
df.drop(axis=1,columns=["Last Name"],inplace=True)

# %%
df.head()
# Out:
#    Emp ID Name Prefix First Name Gender                       E Mail  \
# 0  850297         Ms.     Shawna      F        shawna.buck@gmail.com
# 1  304721         Mr.  Nathaniel      M  nathaniel.burke@walmart.com
# 2  412317        Drs.  Elisabeth      F   elisabeth.foster@gmail.com
# 3  621375        Mrs.     Briana      F   briana.lancaster@yahoo.com
# 4  787549        Hon.    Estella      F     estella.potter@gmail.com
#
#   Date of Birth       Time of Birth  Age in Yrs.  Weight in Kgs.  \
# 0    1971-12-12 2019-08-17 06:34:47        45.66              44
# 1    1993-10-31 2019-08-17 02:02:38        23.76              52
# 2    1994-11-26 2019-08-17 15:48:27        22.68              42
# 3    1975-11-24 2019-08-17 21:44:16        41.70              43
# 4    1995-03-13 2019-08-17 21:30:28        22.39              58
#
#   Date of Joining  Salary                County       City State
# 0      2010-12-18  119090                 Clark  Las Vegas    NV
# ...

# %%
# Out:
# '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]'

# %%
df.drop(axis=1,columns=["Name Prefix","Last Name","Father's Name","Mother's Name"],inplace=True)

# %%
df[df["Country"]=='Fresno']
# Out:
#      Emp ID First Name Gender                     E Mail Date of Birth  \
# 16   265124      Tonia      F      tonia.burns@gmail.com    1985-04-19
# 26   865628    Desmond      M   desmond.wynn@hotmail.com    1992-07-09
# 760  706151    Esteban      M  esteban.finch@walmart.com    1978-07-23
#
#           Time of Birth  Age in Yrs.  Weight in Kgs. Date of Joining  \
# 16  2019-08-10 22:44:02        32.30              50      2014-09-12
# 26  2019-08-10 04:39:00        25.07              58      2013-10-01
# 760 2019-08-10 16:15:37        39.04              64      2013-05-02
#
#      Age in Company (Years)  Salary    Phone No.  Country
# 16                     2.88  102274  209-631-5424  Fresno
# 26                     3.82   79476  209-319-3405  Fresno
# 760                    4.24   84511  209-464-5164  Fresno

# %%
cdtn=df['Salary'] > 100000

# %%
df[cdtn]
# Out:
#      Emp ID First Name Gender                           E Mail Date of Birth  \
# 0    850297     Shawna      F            shawna.buck@gmail.com    1971-12-12
#
#         Time of Birth  Age in Yrs.  Weight in Kgs. Date of Joining  \
# 0 2019-08-10 06:34:47        45.66              44      2010-12-18
# 1 2019-08-10 02:02:38        23.76              52      2017-04-25
# 2 2019-08-10 15:48:27        22.68              42      2017-03-27
# 3 2019-08-10 21:44:16        41.70              43      2003-02-25
# 4 2019-08-10 21:30:28        22.39              58      2016-10-11
#
#    Age in Company (Years)  Salary    Phone No.                Country
# ...

# %%
s=df['Country'].isin(['Clark','Lake'])
df[s]
# Out:
#      Emp ID First Name Gender                       E Mail Date of Birth  \
# 0    850297     Shawna      F        shawna.buck@gmail.com    1971-12-12
# 1    304721  Nathaniel      M  nathaniel.burke@walmart.com    1993-10-31
# 3    621375     Briana      F   briana.lancaster@yahoo.com    1975-11-24
# 28   932453    Beatriz      F    beatriz.knowles@gmail.com    1984-02-25
# 127  825853    Dominic      M     dominic.mosley@gmail.com    1996-07-19
# 169  871610     Kenton      M      kenton.moreno@shell.com    1993-01-19
# 184  974444     Luther      M        luther.mcneil@aol.com    1992-03-31
# 223  586207     Michel      M       michel.finch@gmail.com    1986-06-26
# 716  473773     Stacey      M     stacey.workman@gmail.com    1966-03-26
# 764  901588    Mariana      F       mariana.mcneil@aol.com    1961-03-25
#
#           Time of Birth  Age in Yrs.  Weight in Kgs. Date of Joining  \
# 0   2019-08-10 06:34:47        45.66              44      2010-12-18
# ...

# %%
df[df["Salary"].between(80000,100000)]
# Out:
#      Emp ID Name Prefix  First Name Gender                            E Mail  \
# 7    159108        Mrs.      Shanna      F            shanna.silva@gmail.com
# 15   673049         Dr.        Cole      M               cole.jensen@aol.com
# 17   300693         Mr.         Tod      M           tod.holcomb@outlook.com
# 23   513011         Ms.        Tara      F             tara.forbes@gmail.com
# 24   290808         Mr.       Josef      M           josef.griffin@yahoo.com
# 35   350367         Mr.     Rudolph      M            rudolph.gordon@aol.com
# 47   201710         Ms.       Karyn      F           karyn.christian@aol.com
# 48   722543         Ms.        Lesa      F                lesa.hughes@bp.com
# 52   310986        Drs.   Maryellen      F  maryellen.mcfadden@hotmail.co.uk
# 53   323914         Mr.      German      M             german.carney@aol.com
# 56   434046        Mrs.      Bianca      F          bianca.langley@gmail.com
# ...

# %%
df[df["Weight in Kgs."].between(40,50)].sort_values("Weight in Kgs.")
# Out:
#      Emp ID Name Prefix First Name Gender                          E Mail  \
# 427  854365         Ms.      Kelly      F        kelly.spence@yahoo.co.uk
# 353  587373        Drs.    Lillian      F        lillian.atkinson@aol.com
# 547  689587         Ms.        Ava      F                ava.kane@aol.com
# 189  358935         Ms.  Anastasia      F       anastasia.bowen@gmail.com
# 546  637843         Ms.      Karla      F         karla.barrera@gmail.com
# 369  928723        Mrs.     Angela      F        angela.compton@gmail.com
# 627  801970         Ms.      Becky      F          becky.bolton@gmail.com
# 859  717079        Hon.     Helene      F         helene.franco@shell.com
# 532  316999        Mrs.        Dee      F                dee.love@ibm.com
# 858  924252        Hon.     Cecile      F              cecile.ross@bp.com
# 312  129426        Drs.       Lana      F          lana.hayes@hotmail.com
# 514  999475         Ms.     Carrie      F         carrie.keller@gmail.com
# ...

# %%
df.head(20)
# Out:
#     Emp ID Name Prefix First Name Gender                           E Mail  \
# 0   850297         Ms.     Shawna      F            shawna.buck@gmail.com
# 1   304721         Mr.  Nathaniel      M      nathaniel.burke@walmart.com
# 2   412317        Drs.  Elisabeth      F       elisabeth.foster@gmail.com
# 3   621375        Mrs.     Briana      F       briana.lancaster@yahoo.com
# 4   787549        Hon.    Estella      F         estella.potter@gmail.com
# 5   520092         Mr.     Lamont      M         lamont.woods@hotmail.com
# 6   795934         Ms.    Melinda      F        melinda.lopez@hotmail.com
# 7   159108        Mrs.     Shanna      F           shanna.silva@gmail.com
# 8   330816         Ms.    Jasmine      F        jasmine.freeman@gmail.com
# 9   532002         Ms.      Madge      F            madge.sargent@aol.com
# 10  612850         Ms.    Bethany      F           bethany.cline@yahoo.ca
# 11  483751       Prof.       Reid      M          reid.randolph@gmail.com
# ...

# %%
df[~df["First Name"].duplicated(keep= False)]
# Out:
#      Emp ID Name Prefix First Name Gender                           E Mail  \
# 0    850297         Ms.     Shawna      F            shawna.buck@gmail.com
# 2    412317        Drs.  Elisabeth      F       elisabeth.foster@gmail.com
# 3    621375        Mrs.     Briana      F       briana.lancaster@yahoo.com
# 4    787549        Hon.    Estella      F         estella.potter@gmail.com
# 6    795934         Ms.    Melinda      F        melinda.lopez@hotmail.com
# 7    159108        Mrs.     Shanna      F           shanna.silva@gmail.com
# 8    330816         Ms.    Jasmine      F        jasmine.freeman@gmail.com
# 9    532002         Ms.      Madge      F            madge.sargent@aol.com
# 10   612850         Ms.    Bethany      F           bethany.cline@yahoo.ca
# 11   483751       Prof.       Reid      M          reid.randolph@gmail.com
# 12   252938        Hon.    Antoine      M        antoine.wiley@verizon.net
# ...

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates(subset["First Name"]))
# Out:
# 1000

# %%
len(df.drop_duplicates(subset=["First Name"],keep="first"))
# Out:
# 792

# %%
df.drop_duplicates(subset=["First Name","State"])
# Out:
#      Emp ID Name Prefix First Name Gender                            E Mail  \
# 0    850297         Ms.     Shawna      F             shawna.buck@gmail.com
# 1    304721         Mr.  Nathaniel      M       nathaniel.burke@walmart.com
# 2    412317        Drs.  Elisabeth      F        elisabeth.foster@gmail.com
# 3    621375        Mrs.     Briana      F        briana.lancaster@yahoo.com
# 4    787549        Hon.    Estella      F          estella.potter@gmail.com
# 5    520092         Mr.     Lamont      M          lamont.woods@hotmail.com
# 6    795934         Ms.    Melinda      F         melinda.lopez@hotmail.com
# 7    159108        Mrs.     Shanna      F            shanna.silva@gmail.com
# 8    330816         Ms.    Jasmine      F         jasmine.freeman@gmail.com
# 9    532002         Ms.      Madge      F             madge.sargent@aol.com
# 10   612850         Ms.    Bethany      F            bethany.cline@yahoo.ca
# ...

# %%
len(df["Name Prefix"].unique())
# Out:
# 7

# %%
df["Name Prefix"].nunique()
# Out:
# 7
